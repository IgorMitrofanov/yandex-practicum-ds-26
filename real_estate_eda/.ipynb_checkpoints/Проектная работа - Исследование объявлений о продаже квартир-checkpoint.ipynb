# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек,-чтение-датафрейма,-описание-столбцов-и-первые-выводы" data-toc-modified-id="Импорт-библиотек,-чтение-датафрейма,-описание-столбцов-и-первые-выводы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек, чтение датафрейма, описание столбцов и первые выводы</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименование-столбцов-датафрейма" data-toc-modified-id="Переименование-столбцов-датафрейма-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименование столбцов датафрейма</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Выводы:-предобработка-данных" data-toc-modified-id="Выводы:-предобработка-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы: предобработка данных</a></span></li></ul></li><li><span><a href="#Расчеты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчеты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчеты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Расчет-и-добавление-в-таблицу-стоимости-квадратного-метра" data-toc-modified-id="Расчет-и-добавление-в-таблицу-стоимости-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчет и добавление в таблицу стоимости квадратного метра</a></span></li><li><span><a href="#Добавление-в-таблицу-день-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="Добавление-в-таблицу-день-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавление в таблицу день недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Добавление-в-таблицу-категории-этажа-квартиры" data-toc-modified-id="Добавление-в-таблицу-категории-этажа-квартиры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Добавление в таблицу категории этажа квартиры</a></span></li><li><span><a href="#Добавление-в-таблицу-отношений-жилой-площади-и-площади-кухни-к-общей-площади" data-toc-modified-id="Добавление-в-таблицу-отношений-жилой-площади-и-площади-кухни-к-общей-площади-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Добавление в таблицу отношений жилой площади и площади кухни к общей площади</a></span></li><li><span><a href="#Выводы:-расчеты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Выводы:-расчеты-и-добавление-результатов-в-таблицу-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы: расчеты и добавление результатов в таблицу</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров-площади,-стоимости,-число-комнат-и-высоты-потолков" data-toc-modified-id="Изучение-параметров-площади,-стоимости,-число-комнат-и-высоты-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров площади, стоимости, число комнат и высоты потолков</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь</a></span><ul class="toc-item"><li><span><a href="#Вывод:-параметр-площадь" data-toc-modified-id="Вывод:-параметр-площадь-4.1.1.1"><span class="toc-item-num">4.1.1.1&nbsp;&nbsp;</span>Вывод: параметр площадь</a></span></li></ul></li><li><span><a href="#Стоимость" data-toc-modified-id="Стоимость-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Стоимость</a></span><ul class="toc-item"><li><span><a href="#Вывод:-параметр-стоимость" data-toc-modified-id="Вывод:-параметр-стоимость-4.1.2.1"><span class="toc-item-num">4.1.2.1&nbsp;&nbsp;</span>Вывод: параметр стоимость</a></span></li></ul></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span><ul class="toc-item"><li><span><a href="#Вывод:-параметр-число-комнат" data-toc-modified-id="Вывод:-параметр-число-комнат-4.1.3.1"><span class="toc-item-num">4.1.3.1&nbsp;&nbsp;</span>Вывод: параметр число комнат</a></span></li></ul></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span><ul class="toc-item"><li><span><a href="#Вывод:-параметр-высота-потолков" data-toc-modified-id="Вывод:-параметр-высота-потолков-4.1.4.1"><span class="toc-item-num">4.1.4.1&nbsp;&nbsp;</span>Вывод: параметр высота потолков</a></span></li></ul></li></ul></li><li><span><a href="#Изучение-длительности-продажи-квартиры" data-toc-modified-id="Изучение-длительности-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение длительности продажи квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод:-изучение-длительности-продажи-квартиры" data-toc-modified-id="Вывод:-изучение-длительности-продажи-квартиры-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод: изучение длительности продажи квартиры</a></span></li></ul></li><li><span><a href="#Фильтрация-редких-и-выбивающихся-значений" data-toc-modified-id="Фильтрация-редких-и-выбивающихся-значений-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Фильтрация редких и выбивающихся значений</a></span><ul class="toc-item"><li><span><a href="#Параметр-площади" data-toc-modified-id="Параметр-площади-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Параметр площади</a></span></li><li><span><a href="#Параметр-стоимости" data-toc-modified-id="Параметр-стоимости-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Параметр стоимости</a></span></li><li><span><a href="#Параметр-числа-комнат" data-toc-modified-id="Параметр-числа-комнат-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Параметр числа комнат</a></span></li><li><span><a href="#Параметр-высоты-потолков" data-toc-modified-id="Параметр-высоты-потолков-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Параметр высоты потолков</a></span></li><li><span><a href="#Параметр-длительность-продажи-квартиры" data-toc-modified-id="Параметр-длительность-продажи-квартиры-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Параметр длительность продажи квартиры</a></span></li><li><span><a href="#Доля-отброшенных-выбросов" data-toc-modified-id="Доля-отброшенных-выбросов-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Доля отброшенных выбросов</a></span></li><li><span><a href="#Вывод:-фильтрация-редких-и-выбивающихся-значений" data-toc-modified-id="Вывод:-фильтрация-редких-и-выбивающихся-значений-4.3.7"><span class="toc-item-num">4.3.7&nbsp;&nbsp;</span>Вывод: фильтрация редких и выбивающихся значений</a></span></li></ul></li><li><span><a href="#Выявление-параметров,-влияющих-на-стоимость-квартиры" data-toc-modified-id="Выявление-параметров,-влияющих-на-стоимость-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выявление параметров, влияющих на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Зависимость-стоимости-от-общей-площади-квартиры" data-toc-modified-id="Зависимость-стоимости-от-общей-площади-квартиры-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость стоимости от общей площади квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-от-общей-площади-квартиры" data-toc-modified-id="Вывод:-зависимость-стоимости-от-общей-площади-квартиры-4.4.1.1"><span class="toc-item-num">4.4.1.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости от общей площади квартиры</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-недвижимости-от-числа-комнат" data-toc-modified-id="Зависимость-стоимости-недвижимости-от-числа-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость стоимости недвижимости от числа комнат</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-от-числа-комнат" data-toc-modified-id="Вывод:-зависимость-стоимости-от-числа-комнат-4.4.2.1"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости от числа комнат</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-от--высоты-потолков" data-toc-modified-id="Зависимость-стоимости-от--высоты-потолков-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость стоимости от  высоты потолков</a></span><ul class="toc-item"><li><span><a href="#Вывод:-Зависимость-стоимости-от-высоты-потолков" data-toc-modified-id="Вывод:-Зависимость-стоимости-от-высоты-потолков-4.4.3.1"><span class="toc-item-num">4.4.3.1&nbsp;&nbsp;</span>Вывод: Зависимость стоимости от высоты потолков</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-от-этажа" data-toc-modified-id="Зависимость-стоимости-квартиры-от-этажа-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость стоимости квартиры от этажа</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-от-этажа" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-от-этажа-4.4.4.1"><span class="toc-item-num">4.4.4.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры от этажа</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-от-числа-водоемов-и-парков-в-радиусе-3-км" data-toc-modified-id="Зависимость-стоимости-от-числа-водоемов-и-парков-в-радиусе-3-км-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Зависимость стоимости от числа водоемов и парков в радиусе 3 км</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-от-числа-водоемов-и-парков-в-радиусе-3-км" data-toc-modified-id="Вывод:-зависимость-стоимости-от-числа-водоемов-и-парков-в-радиусе-3-км-4.4.5.1"><span class="toc-item-num">4.4.5.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости от числа водоемов и парков в радиусе 3 км</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-от-удаленности-от-центра-города" data-toc-modified-id="Зависимость-стоимости-от-удаленности-от-центра-города-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Зависимость стоимости от удаленности от центра города</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-от-удаленности-от-центра-города" data-toc-modified-id="Вывод:-зависимость-стоимости-от-удаленности-от-центра-города-4.4.6.1"><span class="toc-item-num">4.4.6.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости от удаленности от центра города</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-от-даты-размещения" data-toc-modified-id="Зависимость-стоимости-от-даты-размещения-4.4.7"><span class="toc-item-num">4.4.7&nbsp;&nbsp;</span>Зависимость стоимости от даты размещения</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-от-даты-размещения" data-toc-modified-id="Вывод:-зависимость-стоимости-от-даты-размещения-4.4.7.1"><span class="toc-item-num">4.4.7.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости от даты размещения</a></span></li></ul></li><li><span><a href="#Вывод:-выявление-параметров,-влияющих-на-стоимость-квартиры" data-toc-modified-id="Вывод:-выявление-параметров,-влияющих-на-стоимость-квартиры-4.4.8"><span class="toc-item-num">4.4.8&nbsp;&nbsp;</span>Вывод: выявление параметров, влияющих на стоимость квартиры</a></span></li></ul></li><li><span><a href="#Топ-10-населенных-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="Топ-10-населенных-пунктов-с-наибольшим-числом-объявлений-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Топ-10 населенных пунктов с наибольшим числом объявлений</a></span><ul class="toc-item"><li><span><a href="#Вывод:-топ-10-населенных-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="Вывод:-топ-10-населенных-пунктов-с-наибольшим-числом-объявлений-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Вывод: топ-10 населенных пунктов с наибольшим числом объявлений</a></span></li></ul></li><li><span><a href="#Изучение-предложения-квартир" data-toc-modified-id="Изучение-предложения-квартир-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучение предложения квартир</a></span><ul class="toc-item"><li><span><a href="#Вывод:-изучение-предложения-квартир" data-toc-modified-id="Вывод:-изучение-предложения-квартир-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Вывод: изучение предложения квартир</a></span></li></ul></li><li><span><a href="#Анализ-сегмента-квартир-в-центре" data-toc-modified-id="Анализ-сегмента-квартир-в-центре-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Анализ сегмента квартир в центре</a></span><ul class="toc-item"><li><span><a href="#Зависимость-стоимости-от-общей-площади-квартиры-в-центре" data-toc-modified-id="Зависимость-стоимости-от-общей-площади-квартиры-в-центре-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Зависимость стоимости от общей площади квартиры в центре</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-в-центре-от-ее-площади" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-в-центре-от-ее-площади-4.7.1.1"><span class="toc-item-num">4.7.1.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры в центре от ее площади</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-в-центре-от-числа-комнат" data-toc-modified-id="Зависимость-стоимости-квартиры-в-центре-от-числа-комнат-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Зависимость стоимости квартиры в центре от числа комнат</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-в-центре-от-числа-комнат" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-в-центре-от-числа-комнат-4.7.2.1"><span class="toc-item-num">4.7.2.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры в центре от числа комнат</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-в-центре-от--высоты-потолков" data-toc-modified-id="Зависимость-стоимости-квартиры-в-центре-от--высоты-потолков-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Зависимость стоимости квартиры в центре от  высоты потолков</a></span><ul class="toc-item"><li><span><a href="#Вывод:-Зависимость-стоимости-квартиры-в-центре-от-высоты-потолков" data-toc-modified-id="Вывод:-Зависимость-стоимости-квартиры-в-центре-от-высоты-потолков-4.7.3.1"><span class="toc-item-num">4.7.3.1&nbsp;&nbsp;</span>Вывод: Зависимость стоимости квартиры в центре от высоты потолков</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-в-центре-от-этажа" data-toc-modified-id="Зависимость-стоимости-квартиры-в-центре-от-этажа-4.7.4"><span class="toc-item-num">4.7.4&nbsp;&nbsp;</span>Зависимость стоимости квартиры в центре от этажа</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-в-центре-от-этажа" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-в-центре-от-этажа-4.7.4.1"><span class="toc-item-num">4.7.4.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры в центре от этажа</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-в-центре-от-числа-водоемов-и-парков-в-радиусе-3-км" data-toc-modified-id="Зависимость-стоимости-квартиры-в-центре-от-числа-водоемов-и-парков-в-радиусе-3-км-4.7.5"><span class="toc-item-num">4.7.5&nbsp;&nbsp;</span>Зависимость стоимости квартиры в центре от числа водоемов и парков в радиусе 3 км</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-в-центре-от-числа-водоемов-и-парков-в-радиусе-3-км" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-в-центре-от-числа-водоемов-и-парков-в-радиусе-3-км-4.7.5.1"><span class="toc-item-num">4.7.5.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры в центре от числа водоемов и парков в радиусе 3 км</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-в-центре-от-удаленности-от-центра-города" data-toc-modified-id="Зависимость-стоимости-квартиры-в-центре-от-удаленности-от-центра-города-4.7.6"><span class="toc-item-num">4.7.6&nbsp;&nbsp;</span>Зависимость стоимости квартиры в центре от удаленности от центра города</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-в-центре-от-удаленности-от-центра-города" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-в-центре-от-удаленности-от-центра-города-4.7.6.1"><span class="toc-item-num">4.7.6.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры в центре от удаленности от центра города</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-квартиры-в-центре-от-даты-размещения" data-toc-modified-id="Зависимость-стоимости-квартиры-в-центре-от-даты-размещения-4.7.7"><span class="toc-item-num">4.7.7&nbsp;&nbsp;</span>Зависимость стоимости квартиры в центре от даты размещения</a></span><ul class="toc-item"><li><span><a href="#Вывод:-зависимость-стоимости-квартиры-в-центре-от-даты-размещения" data-toc-modified-id="Вывод:-зависимость-стоимости-квартиры-в-центре-от-даты-размещения-4.7.7.1"><span class="toc-item-num">4.7.7.1&nbsp;&nbsp;</span>Вывод: зависимость стоимости квартиры в центре от даты размещения</a></span></li></ul></li><li><span><a href="#Вывод:-анализ-сегмента-квартир-в-центре" data-toc-modified-id="Вывод:-анализ-сегмента-квартир-в-центре-4.7.8"><span class="toc-item-num">4.7.8&nbsp;&nbsp;</span>Вывод: анализ сегмента квартир в центре</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `balcony` — число балконов
# - `ceiling_height` — высота потолков (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# - `first_day_exposition` — дата публикации
# - `floor` — этаж
# - `floors_total` — всего этажей в доме
# - `is_apartment` — апартаменты (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `last_price` — цена на момент снятия с публикации
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `locality_name` — название населённого пункта
# - `open_plan` — свободная планировка (булев тип)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `rooms` — число комнат
# - `studio` — квартира-студия (булев тип)
# - `total_area` — площадь квартиры в квадратных метрах (м²)
# - `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# ### Импорт библиотек, чтение датафрейма, описание столбцов и первые выводы

# %% [markdown]
# Установим библиотеки:

# %%
# !pip install seaborn -U
# !pip install missingno

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Загрузим датафрейм:

# %%
df = pd.read_csv(r'C:\Users\IVMitrofanov\Downloads\real_estate_data.csv', sep='\t', parse_dates=[3])

# %% [markdown]
# Выведем первые 5 строк датафрейма.

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Посмотрим информацию о датафрейме методом info():

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Обозначим найденные проблемы, которые необходимо устранить с помощью предобработки данных:
#
# 1) Названия столбцов имеют приемлемый вид, за исключением столбца `cityCenters_nearest`. Переименуем его в `city_centers_nearest`. Также столбцы `parks_around3000` и `ponds_around3000` переименуем в более приятные глазу - `parks_around_3000` и `ponds_around_3000`.
#
# 2) В датасете есть пропуски во всех столбцах, кроме: `total_images`, `last_price`, `total_area`, `first_day_exposition`, `rooms`, `floor`, `studio`, `open_plan`.
#
# 3) Некоторые значения в столбцах, которые по определению должны быть целыми, имеют вещественный тип (`floors_total`, `balcony`, `parks_around3000`, `ponds_around3000`).

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Запишем длину датафрейма до предобработки, чтобы контролировать потерю данных при предобработке:

# %%
len_df_before = len(df)

# %%
len_df_before
# Out:
# 23699

# %% [markdown]
# ### Переименование столбцов датафрейма

# %% [markdown]
# Сначала переименуем столбцы. Все оставим как есть, за исключением вышеописанных столбцов `cityCenters_nearest`, `parks_around3000` и `ponds_around3000`:

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
df.columns = ['total_images', 'last_price', 'total_area', 'first_day_exposition',
              'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
              'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
              'locality_name', 'airports_nearest', 'city_centers_nearest',
              'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
              'ponds_nearest', 'days_exposition']

# %% [markdown]
# Убедимся, что названия столбцов изменились:

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Выясним долю пропусков в столбцах:

# %%
df.isna().mean()
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.387991
# floors_total            0.003629
# living_area             0.080299
# floor                   0.000000
# is_apartment            0.882906
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.096122
# balcony                 0.486054
# locality_name           0.002068
# airports_nearest        0.233850
# city_centers_nearest    0.232879
# parks_around_3000       0.232837
# parks_nearest           0.659100
# ponds_around_3000       0.232837
# ponds_nearest           0.615596
# days_exposition         0.134225
# dtype: float64

# %% [markdown]
# Визуализируем пропуски с помощью библиотеки `missingno`:

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# По визуализации следует отметить, что шаблон пропусков в столбцах `airports_nearest`, `city_centers_nearest`, `parks_around_3000`, `parks_nearest`, `ponds_nearest` очень схож. Очевидно, что эти данные получены автоматически на основе картографических данных. Причин таких пропусков может быть множество, например у пользователя была отключена передача геопозиции при опубликовании объявления или расстояние до аэропорта слишком большое (геопозиция - маленький поселок). Поскольку эти данные не пригодятся нам в исследовании, мы не будем их касаться. Схожий шаблон пропусков также имеют столбцы `living_area` и `kitchen_area`.

# %% [markdown]
# Пройдемся по каждому столбцу с пропусками:
#
# - `ceiling_height` - 38.7 % пропусков. Очень весомо, скорее всего пропуски значений в этом столбце связаны с тем, что продавец не всегда указывает данный параметр в объявлении. Пропуски нужно будет заполнить, изучим этот вопрос подробнее при исследовательском анализе данных.

# %% [markdown]
# - `floors_total` - Количество пропусков менее 0.4 %. Вероятно, что пользователи не заполнили это поле. Пропусков можно было бы избежать, заполняя данные автоматически на основе адреса. Можно без последствий для датасета **избавится** от пропусков из-за их небольшой доли в данных:

# %%
df.dropna(subset = ['floors_total'], inplace = True)

# %% [markdown]
# - `living_area`, `kitchen_area` - 8.0 и 9.6 % пропусков соотетственно. Скорее всего, так же как и в  `ceiling_height` продавец не указал эти значения в обявлении. Возможно заполнение их усредненными значениями на базе общей площади, но на данном этапе мы не будем этого делать.

# %% [markdown]
# - `balcony`, `is_apartment` - 48.6 и 88.3 % пропусков соотвественно. Если продавец не указал число балконов — скорее всего, их нет. Та же логика и у категории "апартаменты" - если продавец это не указал - скорее всего это не апартаменты. Пропуски в `balcony` **заменим на 0**, а в `is_apartment` на **False**.

# %%
df['balcony'] = df['balcony'].fillna(0)
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# - `locality_name` - менее 0.2 % пропусков. Заполнить их мы не сможем, можно без последствий для датасета **избавится** от этих пропусков.

# %%
df.dropna(subset = ['locality_name'], inplace = True)

# %% [markdown]
# - `airports_nearest` - 23.4 % пропусков. Если данных нет - скорее всего ближайшего аэропорта попросту нет. Такой пропуск мы заполнить не можем, поэтому пусть **останется** *None*.

# %% [markdown]
# - `city_centers_nearest` - 23.3 % пропусков. Возможно такие пропуски возникают не в крупных городах - нужно это проверить. Выведем топ-10 городов, указанных в объявлении, если в столбце `city_centers_nearest` встречается *None*:

# %%
df[df['city_centers_nearest'].isna()]['locality_name'].value_counts().head(10)
# Out:
# посёлок Мурино             520
# Всеволожск                 398
# Гатчина                    307
# деревня Кудрово            299
# Выборг                     237
# Кудрово                    171
# деревня Новое Девяткино    143
# Сертолово                  142
# Кириши                     125
# Сланцы                     112
# Name: locality_name, dtype: int64

# %% [markdown]
# Действительно, похоже что так. Причину появления пропуска мы выяснили, однако подобно столбцу `airports_nearest` заполнить пропуски мы тут не сможем. Кстати, примечательно, что доли пропусков в `airports_nearest` и `city_centers_nearest`, как и их шаблон практически идетичны, что также подтверждает причину возникновения пропусков в этих столбцах.

# %% [markdown]
# - `parks_around_3000`, `ponds_around_3000` - 23.3 % пропусков. Скорее всего пропуск в данных говорит о том, что парка или водоема в радиусе 3 км - нет. Очень похоже на то, что эти пропуски также возникают не в курпных городах, проверим это:

# %%
df[df['parks_around_3000'].isna()]['locality_name'].value_counts().head(10)
# Out:
# посёлок Мурино             520
# Всеволожск                 398
# Гатчина                    307
# деревня Кудрово            299
# Выборг                     237
# Кудрово                    171
# деревня Новое Девяткино    143
# Сертолово                  142
# Кириши                     125
# Сланцы                     112
# Name: locality_name, dtype: int64

# %%
df[df['ponds_around_3000'].isna()]['locality_name'].value_counts().head(10)
# Out:
# посёлок Мурино             520
# Всеволожск                 398
# Гатчина                    307
# деревня Кудрово            299
# Выборг                     237
# Кудрово                    171
# деревня Новое Девяткино    143
# Сертолово                  142
# Кириши                     125
# Сланцы                     112
# Name: locality_name, dtype: int64

# %% [markdown]
# Точное совпадение. Значит причину появления пропусков мы выяснили, будем трактовать пропуски как нулевые значения:

# %%
df['parks_around_3000'] = df['parks_around_3000'].fillna(0)
df['ponds_around_3000'] = df['ponds_around_3000'].fillna(0)

# %% [markdown]
# - `parks_nearest`, `ponds_nearest` - 65.9 и 61.5 % пропусков соотвественно. Эти данные заполнялись автоматически, какая-то доля пропусков возможно связана с тем, что парка или водоема нет в радиусе 3 км. Если это так, то доля нулей в столбцах `parks_around_3000` и `ponds_around_3000` должна примерно совпадать с долей пропусков в столбцах-спутниках `parks_nearest`, `ponds_nearest`.

# %% [markdown]
# Доля нулей в столбце `parks_around_3000` и `ponds_around_3000`:

# %%
df.query('parks_around_3000 == 0')['parks_around_3000'].count()/df.shape[0]
# Out:
# 0.6594101421599831

# %%
df.query('ponds_around_3000 == 0')['parks_around_3000'].count()/df.shape[0]
# Out:
# 0.6165499681731381

# %% [markdown]
# Доля нулей в столбцах `parks_around_3000` и `ponds_around_3000` приблизительно совпадают с долей пропусков в столбцах-спутниках `parks_nearest`, `ponds_nearest`. Отсюда вывод - пропуски в столбцах `parks_nearest`, `ponds_nearest` находятся по причине отсутсвия поблизости парков и водоемов.

# %% [markdown]
# Заполнить такие пропуски мы не можем (подобно всем столбцам `_nearest`), поэтому **оставим** эти пропуски.

# %% [markdown]
# - `days_exposition` - 13.4 % пропусков. Возможно объявление еще не было снято, поэтому эти значения не заполнились. Можно заполнить медианным значением, но так как мы будем исследовать эту величину в ходе работы - **оставим пропуски** и не будем искажать данные. Возможная причина пропусков - сбой при сборе или обработке данных.

# %% [markdown]
# Посмотрим, как изменилась доля пропусков в датасете:

# %%
df.isna().mean()
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.385487
# floors_total            0.000000
# living_area             0.079143
# floor                   0.000000
# is_apartment            0.000000
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.094292
# balcony                 0.000000
# locality_name           0.000000
# airports_nearest        0.234415
# city_centers_nearest    0.233439
# parks_around_3000       0.000000
# parks_nearest           0.659240
# ponds_around_3000       0.000000
# ponds_nearest           0.616550
# days_exposition         0.134564
# dtype: float64

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Для начала вспомним типы данных столбцов:

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                     float64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                   float64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                        float64
# locality_name                   object
# airports_nearest               float64
# city_centers_nearest           float64
# parks_around_3000              float64
# parks_nearest                  float64
# ponds_around_3000              float64
# ponds_nearest                  float64
# days_exposition                float64
# dtype: object

# %% [markdown]
# Приведем значения в столбцах `floors_total`, `balcony`, `parks_around3000`, `ponds_around3000` в целый тип, так как они по определению могут быть только целыми:

# %%
df['floors_total'] = df['floors_total'].astype(int)
df['balcony'] = df['balcony'].astype(int)
df['parks_around_3000'] = df['parks_around_3000'].astype(int)
df['ponds_around_3000'] = df['ponds_around_3000'].astype(int)

# %% [markdown]
# Убедимся в преобразовании типов данных:

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                     float64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int32
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int32
# locality_name                   object
# airports_nearest               float64
# city_centers_nearest           float64
# parks_around_3000                int32
# parks_nearest                  float64
# ponds_around_3000                int32
# ponds_nearest                  float64
# days_exposition                float64
# dtype: object

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Для начала посмотрим количество явных дубликатов в датасете:

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Отлично - явных дубликатов нет. Теперь исследуем значения в столбце `locality_name`, в нем могут быть неявные дубликаты связанные с регистром и различным написанием городов и насленных пунктов.

# %%
df['locality_name'].value_counts()
# Out:
# Санкт-Петербург                    15651
# посёлок Мурино                       520
# посёлок Шушары                       439
# Всеволожск                           398
# Пушкин                               369
#                                    ...
# поселок Каложицы                       1
# посёлок Платформа 69-й километр        1
# поселок Почап                          1
# поселок Гончарово                      1
# посёлок Дзержинского                   1
# Name: locality_name, Length: 364, dtype: int64

# %%
df['locality_name'].unique(), len(df['locality_name'].unique())
# Out:
# (array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#         'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#         'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#         'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#         'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#         'деревня Новое Девяткино', 'посёлок Металлострой',
#         'посёлок городского типа Лебяжье',
#         'посёлок городского типа Сиверский', 'поселок Молодцово',
#         'поселок городского типа Кузьмоловский',
#         'садовое товарищество Новая Ропша', 'Павловск',
#         'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#         'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#         'поселок городского типа Ефимовский', 'посёлок Плодовое',
#         'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Приведем все к нижнему регистру и уберем букву "ё". Из всего названия населенных пунктов выделим только его название, а обозначение - убирем.

# %%
df['locality_name'] = df['locality_name'].str.lower()
df['locality_name'] = df['locality_name'].str.replace('ё','е')
df['locality_name'] = df['locality_name'].str.replace('поселок ','')
df['locality_name'] = df['locality_name'].str.replace('городского типа ','')
df['locality_name'] = df['locality_name'].str.replace('при железнодорожной станции  ','')
df['locality_name'] = df['locality_name'].str.replace('деревня ','')
df['locality_name'] = df['locality_name'].str.replace('село ','')
df['locality_name'] = df['locality_name'].str.replace('садовое товарищество ','')
df['locality_name'] = df['locality_name'].str.replace('коттеджный ','')
df['locality_name'] = df['locality_name'].str.replace('городской ','')
df['locality_name'] = df['locality_name'].str.replace(' поле','')

# %% [markdown]
# Убедимся, что значения приняли нужный вид:

# %%
df['locality_name'].unique(), len(df['locality_name'].unique())
# Out:
# (array(['санкт-петербург', 'шушары', 'янино-1', 'парголово', 'мурино',
#         'ломоносов', 'сертолово', 'петергоф', 'пушкин', 'кудрово',
#         'коммунар', 'колпино', 'красный бор', 'гатчина', 'федоровское',
#         'выборг', 'кронштадт', 'кировск', 'новое девяткино',
#         'металлострой', 'лебяжье', 'сиверский', 'молодцово',
#         'кузьмоловский', 'новая ропша', 'павловск', 'пикколово',
#         'всеволожск', 'волхов', 'кингисепп', 'приозерск', 'сестрорецк',
#         'куттузи', 'аннино', 'ефимовский', 'плодовое', 'заклинье',
#         'торковичи', 'первомайское', 'красное село', 'понтонный',
#         'сясьстрой', 'старая', 'лесколово', 'новый свет', 'сланцы',
#         'путилово', 'ивангород', 'шлиссельбург', 'никольское',
#         'зеленогорск', 'сосновый бор', 'оржицы', 'кальтино', 'романовка',
#         'бугры', 'рощино', 'кириши', 'луга', 'волосово', 'отрадное',
#         'павлово', 'оредеж', 'копорье', 'молодежное', 'тихвин', 'победа',
# ...

# %% [markdown]
# Как минимум 56 дублей в уникальных названиях устранено.

# %%
df['locality_name'].value_counts()
# Out:
# санкт-петербург    15651
# мурино               586
# кудрово              470
# шушары               439
# всеволожск           398
#                    ...
# алексеевка             1
# белоостров             1
# пельгора               1
# каложицы               1
# дзержинского           1
# Name: locality_name, Length: 308, dtype: int64

# %% [markdown]
# Снова посчитаем количество явных дубликатов:

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов не возникло.

# %% [markdown]
# Посмотрим долю отброшенной информации при предобработке:

# %%
len_df_ater = len(df)

# %%
len_df_ater
# Out:
# 23565

# %%
1 - len_df_ater / len_df_before
# Out:
# 0.005654247014642011

# %% [markdown]
# ### Выводы: предобработка данных

# %% [markdown]
# В данном разделе мы поработали над предобработкой датасета, а именно:
#
# 1) изменили названия столбцов - все названия в низком регистре и в змеиной нотации;
#
# 2) заполнили пропуски там, где это возможно. При этом данные столбцы остались с пропусками:
#
# - `ceiling_height` - 38.7 % пропусков, вероятная причина - продавец не указал параметр;
# - `living_area` - 8.0 % пропусков, вероятная причина - продавец не указал параметр;
# - `kitchen_area` - 9.6 % пропусков, вероятная причина - продавец не указал параметр;
# - `airports_nearest` - 23.4 % пропусков, причина - объявление находится в маленьком городе и аэропорта нет;
# - `city_centers_nearest` - 23.3% пропусков, причина - объявление находится в маленьком городе, системе неясно что считать за центр города или он слишком далеко;
# - `parks_nearest` - 65.9 % пропусков, причина - парка нет в радиусе 3 км;
# - `ponds_nearest` - 61.5 % пропусков, причина - водоема нет в радиусе 3 км;
# - `days_exposition` - 13.4 % пропусков, вероятная причина - сбой при сборе или обработке данных.
#
# 3) Привели столбец с датой `first_day_exposition` к формату *datetime*, а также изменили тип данных столбцов `floors_total`, `balcony`, `parks_around3000`, `ponds_around3000` на целочисленный, так как значения в этих столбцах являются целыми по определению;
#
# 4) привели все значения в столбце `locality_name` к нижнему регистру и избавились от дублирования населенных пунктов из-за буквы "ё", это позволит "чище" провести анализ данных;
#
# 5) дубликатов в датасете не обнаружено.
#
# При предобработке отброшено менее 0.6% информации.

# %% [markdown]
# ## Расчеты и добавление результатов в таблицу

# %% [markdown]
# ### Расчет и добавление в таблицу стоимости квадратного метра

# %% [markdown]
# Посчитаем и добавим в таблицу стоимости квартиры за $м^{2}$:

# %%
df['price_for_square_meter'] = df['last_price'] / df['total_area']

# %% [markdown]
# ### Добавление в таблицу день недели, месяц и год публикации объявления

# %% [markdown]
# Добавим в таблицу день недели, месяц и год публикации:

# %%
df['day_of_week'] = df['first_day_exposition'].dt.dayofweek
df['day_of_week'].head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    4
# 4    1
# Name: day_of_week, dtype: int64

# %%
df['month'] = df['first_day_exposition'].dt.month
df['month'].head()
# Out:
# 0     3
# 1    12
# 2     8
# 3     7
# 4     6
# Name: month, dtype: int64

# %%
df['year'] = df['first_day_exposition'].dt.year
df['year'].head()
# Out:
# 0    2019
# 1    2018
# 2    2015
# 3    2015
# 4    2018
# Name: year, dtype: int64

# %% [markdown]
# ### Добавление в таблицу категории этажа квартиры

# %% [markdown]
# Добавим в таблицу варианты для этажа квартиры: первый, последний, другой. Для этого напишем функцию *floor_category(row)*, которая будет распределять этажи на эти категории:

# %%
count_errors = 0
def floor_category(row):
    floor = row[0]
    floors_total = row[1]
    try:
        if floor == 1:
            return 'первый'
        if floor == floors_total:
            return 'последний'
        return 'другой'
    except:
        count_errors += count_errors

# %% [markdown]
# Применим функцию к столбцу, посмотрим результат ее исполнения и проверим наличие ошибок:

# %%
df['floor_category'] = df[['floor', 'floors_total']].apply(floor_category, axis=1)
df['floor_category'].head()
# Out:
# 0    другой
# 1    первый
# 2    другой
# 3    другой
# 4    другой
# Name: floor_category, dtype: object

# %%
count_errors
# Out:
# 0

# %% [markdown]
# При выполнении функции ошибок не обнаружно.

# %% [markdown]
# ### Добавление в таблицу отношений жилой площади и площади кухни к общей площади

# %% [markdown]
# Посчитаем и добавим в таблицу **отношение жилой площади к общей площади** и **отношение площади кухни к общей площади**:

# %%
df['living_area_to_total_area'] = df['living_area'] / df['total_area']
df['living_area_to_total_area'].head()
# Out:
# 0    0.472222
# 1    0.460396
# 2    0.612500
# 3         NaN
# 4    0.320000
# Name: living_area_to_total_area, dtype: float64

# %%
df['kitchen_area_to_total_area'] = df['kitchen_area'] / df['total_area']
df['kitchen_area_to_total_area'].head()
# Out:
# 0    0.231481
# 1    0.272277
# 2    0.148214
# 3         NaN
# 4    0.410000
# Name: kitchen_area_to_total_area, dtype: float64

# %% [markdown]
# Напомним, что *None* возникли из-за наличия пропусков в столбцах `living_area` и `kitchen_area`.

# %% [markdown]
# ### Выводы: расчеты и добавление результатов в таблицу

# %% [markdown]
# Подведем итог раздела. В датафрейм добавлены столбцы:
#
# - `price_for_square_meter` - содержит стоимость недвмижимости за 1 $м^{2}$;
# - `day_of_week` - содержит день недели публикации объявления (0 соотвествует понедельнику, а 6 - воскресенью);
# - `month` - содержит номер месяца публикации объявления;
# - `year` - содержит год публикации объявления;
# - `floor_category` - содержит категории этажа квартиры (первый, другой, последний);
# - `living_area_to_total_area` - содержит отношение жилой площади к общей площади;
# - `kitchen_area_to_total_area` - содержит отношение площади кухни к общей площади.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Напишем функцию для получения информации о требуемом параметре:

# %%
def column_info(df, column):
    print('Распределение значений:')
    df[column].plot(kind='hist', grid=True,bins='fd', figsize=(16, 6), title=column)
    plt.show()
    print('Диаграмма размаха:')
    df.boxplot(column, figsize=(16, 6))
    plt.show()
    print('Основные статистические характеристики:')
    print()
    print(df[column].describe())

# %% [markdown]
# *Примечание*
#
# Для определения оптимального количества "корзин" в гистограмме будем пользоваться правилом Фридмана-Дьякониса:
#
# $$n = 2\cdot IQR\cdot N^{-1/3}$$
#
# где $IQR = Q_{3} - Q_{1}$ - интерквартильное расстояние
#
# Будем передовать *fd* параметру *bins*.

# %% [markdown]
# ### Изучение параметров площади, стоимости, число комнат и высоты потолков

# %% [markdown]
# Изучим параметры: площадь, стоимость, число комнат, высота потолков и построим гистограммы для каждого из них.

# %% [markdown]
# #### Площадь

# %% [markdown]
# Получим основную информацию о параметре `total_area`:

# %%
column_info(df, 'total_area')
# Out:
# Распределение значений:
# Диаграмма размаха:
# Основные статистические характеристики:
#
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Смущает значение площади, равное 900 $м^{2}$, посмотрим такие строки в датаферйме:

# %%
df.query('total_area == 900')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 19540             8  420000000.0       900.0           2017-12-06     12
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 19540             2.8            25        409.7     25         False  ...
#
#        ponds_around_3000  ponds_nearest  days_exposition  \
# 19540                  2          318.0            106.0
#
#        price_for_square_meter day_of_week  month  year  floor_category  \
# 19540           466666.666667           2     12  2017       последний
#
#        living_area_to_total_area  kitchen_area_to_total_area
# 19540                   0.455222                    0.124444
#
# [1 rows x 29 columns]

# %% [markdown]
# Судя по остальным параметрам - похоже на правду. Значит это просто редкое значение, а не аномалия.

# %% [markdown]
# Имеем несколько длинных пиков, скорее всего это объявления с типовыми планировками однокомнатных, двухкомнатных и т.д. квартир.

# %% [markdown]
# Также имеется очень длинный хвост до максимального значения площади в 900 $м^{2}$. Такое вполне возможно, но число объявлений с квартирами таких площадей стремится к нулю среди массы остальных объявлений.

# %% [markdown]
# ##### Вывод: параметр площадь

# %% [markdown]
# 1) Напоминает распределение Пуассона.
#
# 2) Распределение параметра площади квартир в объявлениях имеет длинный хвост до значений 900 $м^{2}$, причем  - это реальное объявление (просто очень редкое), а не аномалия.
#
# 3) В распределении есть несколько длинных пиков, скорее всего это объявления с типовыми планировками однокомнатных, двухкомнатных и т.д. квартир.
#
# 4) Среднее значение - 60 $м^{2}$, медианное 52 $м^{2}$.
#
# 5) Никаких аномальных значений в параметре не обнаружено.

# %% [markdown]
# #### Стоимость

# %% [markdown]
# Получим основные статистические характеристики для параметра стоимости квартиры `last_price`:

# %%
column_info(df, 'last_price')
# Out:
# Распределение значений:
# Диаграмма размаха:
# Основные статистические характеристики:
#
# count    2.356500e+04
# mean     6.540058e+06
# std      1.091093e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.646000e+06
# 75%      6.790000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Посмотрим строки в датафрейме, где значение стоимости квартиры равно 763 млн.:

# %%
df.query('last_price == 763000000')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 12971            19  763000000.0       400.0           2017-09-30      7
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 12971             NaN            10        250.0     10         False  ...
#
#        ponds_around_3000  ponds_nearest  days_exposition  \
# 12971                  3          756.0             33.0
#
#        price_for_square_meter day_of_week  month  year  floor_category  \
# 12971               1907500.0           5      9  2017       последний
#
#        living_area_to_total_area  kitchen_area_to_total_area
# 12971                      0.625                         NaN
#
# [1 rows x 29 columns]

# %% [markdown]
# Судя по остальным данным - это не аномалия, а просто редкое значение.

# %% [markdown]
# Очень "острый" клюв и длинный "хвост". Из-за длинного "хвоста" гистограмма очень плохо читается.

# %% [markdown]
# ##### Вывод: параметр стоимость

# %% [markdown]
# 1) Напоминает распределение Пуассона.
#
# 2) Распределение параметра стоимости квартир в объявлениях имеет очень длинный хвост до значения 763 млн, причем это реальное объявление, а не аномалия.
#
# 3) Пик распределения объявлений приходится на квартиры со стоимостью около 4-5 млн.
#
# 4) Среднее значение 6.54 млн, медианное значение - 4.62 млн.
#
# 5) Никаких аномальных значений в параметре не обнаружено.

# %% [markdown]
# #### Число комнат

# %% [markdown]
#  Получим основные статистические характеристики для параметра числа комнат квартиры `rooms`:

# %%
column_info(df, 'rooms')
# Out:
# Распределение значений:
# Диаграмма размаха:
# Основные статистические характеристики:
#
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Выявлен неявный пропуск данных - количество комнат 0. В действительности такого быть не может. Посмотрим долю подобных значений в датафрейе:

# %%
df.query('rooms == 0')['rooms'].count() / df.shape[0]
# Out:
# 0.008232548270740506

# %% [markdown]
# Таких пропусков около 0.8 %, избавимся от них:

# %%
df = df.query("rooms != 0")

# %% [markdown]
# Убедимся, что пропуски исчезли:

# %%
df.query('rooms == 0')['rooms'].count() / df.shape[0]
# Out:
# 0.0

# %% [markdown]
# Посмотрим как изменились основные статистические характеристики:

# %%
df['rooms'].describe()
# Out:
# count    23371.000000
# mean         2.087844
# std          1.066362
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Немного повлияло на среднее значение, но в целом статистические характеристики не изменились.

# %% [markdown]
# В целом все выглядит ожидаемо, кроме максимального значения равному 19 комнатам. Посмотрим строки в датафрейме с числом квартир равное 19 комнатам:

# %%
df.query('rooms == 19')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 14498             6  32250000.0       374.6           2018-06-09     19
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 14498             NaN             5        264.5      2         False  ...
#
#        ponds_around_3000  ponds_nearest  days_exposition  \
# 14498                  2          548.0            114.0
#
#        price_for_square_meter day_of_week  month  year  floor_category  \
# 14498            86091.831287           5      6  2018          другой
#
#        living_area_to_total_area  kitchen_area_to_total_area
# 14498                   0.706086                    0.073679
#
# [1 rows x 29 columns]

# %% [markdown]
# Судя по площади - выглядит вполне достоверно. Построим гистограмму:

# %%
df['rooms'].plot(
    kind='hist',
    grid=True,
    bins='fd',
    figsize=(16, 6));

# %% [markdown]
# Хочется получить цифры. Посмотрим долю квартир с разным числом комнат (до 5 комнат):

# %% [markdown]
# Однокомнатные:

# %%
df.query('rooms == 1')['rooms'].count() / df.shape[0]
# Out:
# 0.3424757177698858

# %% [markdown]
# Двухкомнатные:

# %%
df.query('rooms == 2')['rooms'].count() / df.shape[0]
# Out:
# 0.3378973942064952

# %% [markdown]
# Трехкомнатные:

# %%
df.query('rooms == 3')['rooms'].count() / df.shape[0]
# Out:
# 0.24727226049377435

# %% [markdown]
# Четырехкомнатные:

# %%
df.query('rooms == 4')['rooms'].count() / df.shape[0]
# Out:
# 0.05014761884386633

# %% [markdown]
# Пятикомнатные:

# %%
df.query('rooms == 5')['rooms'].count() / df.shape[0]
# Out:
# 0.013906122972915151

# %% [markdown]
# ##### Вывод: параметр число комнат

# %% [markdown]
# 1) Напоминает распределение Пуассона.
#
# 2) Распределение параметра числа комнат квартир в объявлениях имеет длинный хвост до значения равного 19 комнатам. Объявление с квартирой, где число комнат равно 19 выглядит достоверным.
#
# 3) Пик распределения объявлений приходится на однокомнатные квартиры, медианное значение - двухкомнатные квартиры.
#
# 4) Примечательно, что более двух третьих (~ 68.0%) всех объявлений с квартирами - это однокомнатные и двухкомнатные квартиры. Трехкомнатные квартиры встречаются примерно в четверти (~ 25.0%) всех объявлений. Четырёхкомнатные и пятикомнатные квартиры встречаются в 5.0, 1.4% из всех объявлений соответственно.

# %% [markdown]
# #### Высота потолков

# %% [markdown]
# Получим основные статистические характеристики для параметра высоты потолков квартиры `ceiling_height`:

# %%
column_info(df, 'ceiling_height')
# Out:
# Распределение значений:
# Диаграмма размаха:
# Основные статистические характеристики:
#
# count    14399.000000
# mean         2.769387
# std          1.249022
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Возникают вопросы к минимальному и максимальному значению высоты потолков - 1 и 100 метров соотвественно. В действительности такого быть не может, смотреть срез по датафрейму не имеет никакого смысла.

# %% [markdown]
# Построим гистограмму:

# %%
df['ceiling_height'].plot(
    kind='hist',
    grid=True,
    bins='fd',
    figsize=(16, 6));

# %% [markdown]
# Гистограмма не читаема из-за максимума высоты потолка в 100 метров. Видно, что основная масса значений лежит в интервале от 0 до 5 метров. Ограничим область ее построения:

# %%
df['ceiling_height'].plot(
    kind='hist',
    grid=True,
    bins='fd',
    figsize=(16, 6),
    range=(0, 5));

# %% [markdown]
# Интересное распределение, выделяются отдельные пики - скорее всего это типовая высота потолков в многоквартирных домах. Большинство объявлений приходятся на квартиры с высотой потолков равной 2.65 метров.

# %% [markdown]
# ##### Вывод: параметр высота потолков

# %% [markdown]
# 1) Выделяются отдельные пики в распределении - скорее всего это типовая высота потолков в многоквартирных домах, построенных в разное время и по разным стандартам.
#
# 2) Стоит также учесть, что в данном столбце было очень много пропущенных значений (38.7 %) - поэтому распределение в основном состоит из отдельных пиков.
#
# 3) Замечены аномальные низкие потолки (порядка 1 метра) и аномально высокие потолки (порядка 100 метров) - скорее всего это пользовательская ошибка при вводе данных или ошибка при сборе или обработке данных.

# %% [markdown]
# ### Изучение длительности продажи квартиры

# %% [markdown]
# Получим основные статистические характеристики для параметра время продажи квартиры days_exposition

# %%
column_info(df, 'days_exposition')
# Out:
# Распределение значений:
# Диаграмма размаха:
# Основные статистические характеристики:
#
# count    20214.000000
# mean       181.368458
# std        220.094368
# min          1.000000
# 25%         45.000000
# 50%         96.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Смущает максимальное время продажи квартиры - 1580 дней, это приблизительно равно 4.3 годам, достаточно долго. Посмотрим строчки в датафрейме, где время продажи квартиры равно 1580 дней:

# %%
df.query('days_exposition == 1580')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 18843            11   3500000.0        48.2           2014-12-15      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 18843             2.5             5         27.4      2         False  ...
#
#        ponds_around_3000  ponds_nearest  days_exposition  \
# 18843                  0            NaN           1580.0
#
#        price_for_square_meter day_of_week  month  year  floor_category  \
# 18843            72614.107884           0     12  2014          другой
#
#        living_area_to_total_area  kitchen_area_to_total_area
# 18843                   0.568465                    0.159751
#
# [1 rows x 29 columns]

# %% [markdown]
# Может быть квартиру продали, а объявление забыли закрыть? А может быть, что продажа действительно занимала такое время. В любом случае ответить на этот вопрос мы не можем.

# %% [markdown]
# Построим гистограмму:

# %%
df['days_exposition'].plot(
    kind='hist', 
    grid=True, 
    bins='fd', 
    figsize=(16, 6));

# %% [markdown]
# Распределение объявлений с длительностью продажи квартиры похоже на распределение Пуассона и имеет очень длинный хвост (до 1580 дней). Пик распределения приходится примерно на значение в 100 дней.

# %% [markdown]
# #### Вывод: изучение длительности продажи квартиры

# %% [markdown]
# 1) Среднее значение длительности продажи квартиры составляет 181 день (приблизительно 6 месяцев).
#
# 2) Медианное время продажи квартиры - 96 дней (приблизительно 3 месяца).
#
# 3) Обычно квартиры продаются за 3 месяца.
#
# 4) Продажу квартиры можно считать быстрой, если она продалась менее чем за 45 дней (первый квартиль).
#
# 5) Продажу квартиры можно считать долгой, если она продалась более чем за 232 дня (третий квартиль).
#
# 6) Имеются аномально большие значения длительности продажи квартиры (до 1580 дней).

# %% [markdown]
# ### Фильтрация редких и выбивающихся значений

# %% [markdown]
# #### Параметр площади

# %% [markdown]
# Построим диаграмму размаха для определения редких и выбивающихся значений:

# %%
df.boxplot('total_area', figsize=(16, 6));

# %% [markdown]
# Согласно теории выбросов, явными выбросами считаются значения, выходящие за $3 \cdot IQR$, где $IQR = Q_{3} - Q_{1}$.

# %% [markdown]
# Запишем квартили и интерквартильные расстояния в соотвествующие переменные, и посчитаем верхнюю грацниу "усов":

# %%
Q1 =  df['total_area'].quantile(0.25)
Q3 = df['total_area'].quantile(0.75)
IQR = Q3 - Q1
Q3 + 3 * IQR
# Out:
# 159.39999999999998

# %% [markdown]
# Судя по расчету, все значения общей площади в объявлениях превышающие 159 $м^{2}$ - выбросы. Посчитаем их долю среди всех объявлений:

# %%
1 - df.query('@Q1 - 3*@IQR < total_area < @Q3 + 3*@IQR')['total_area'].count() / df.shape[0]
# Out:
# 0.019982029010311875

# %% [markdown]
# Доля явных выбросов в столбце `total_area` - 2.0 %. Отбрасывать выбросы не будем, так как это просто достаточно редкие квартиры и эти выбросы являются ценной информацией.

# %% [markdown]
# #### Параметр стоимости

# %% [markdown]
# Продолжим работу уже с отфильтрованным датасетом. Построим диаграмму размаха для параметра стоимости квартиры:

# %%
df.boxplot('last_price', figsize=(16, 6));

# %% [markdown]
# Переопределим квартили и интерквартильные расстояния для параметра стоимости квартиры, и посчитаем верхнюю грацниу "усов":

# %%
Q1 =  df['last_price'].quantile(0.25)
Q3 = df['last_price'].quantile(0.75)
IQR = Q3 - Q1
Q3 + 3 * IQR
# Out:
# 16850000.0

# %% [markdown]
# Посчитаем долю явных выбросов:

# %%
(1 - df.query('@Q1 - 3*@IQR < last_price < @Q3 + 3*@IQR')['last_price'].count() / df.shape[0])
# Out:
# 0.04188952120148903

# %% [markdown]
# Доля явных выбросов в столбце `last_price` - 4.1%, так как это все таки стоимость квартиры и задается она пользователями - удалять выбросы не будем, это ценная информация.

# %% [markdown]
# #### Параметр числа комнат

# %% [markdown]
# Построим диаграмму размаха для параметра числа комнат квартиры:

# %%
df.boxplot('rooms', figsize=(16, 6));

# %%
df['rooms'].value_counts()
# Out:
# 1     8004
# 2     7897
# 3     5779
# 4     1172
# 5      325
# 6      104
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# 12       1
# Name: rooms, dtype: int64

# %% [markdown]
# Объявлений с числом квартир более 10 очень мало, такие данные едва подходят для анализа. Однако, удалять их не будем.

# %% [markdown]
# #### Параметр высоты потолков

# %% [markdown]
# Построим диаграмму размаха для параметра высоты потолков квартиры:

# %%
df.boxplot('ceiling_height', figsize=(16, 6));

# %%
df['ceiling_height'].describe()
# Out:
# count    14399.000000
# mean         2.769387
# std          1.249022
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# 75% значений лежит в пределах от 1 до 2.8 метров. Переопределим квартили и интерквартильные расстояния для параметра стоимости квартиры, и посчитаем верхнюю грацниу "усов":

# %%
Q1 =  df['ceiling_height'].quantile(0.25)
Q3 = df['ceiling_height'].quantile(0.75)
IQR = Q3 - Q1
Q3 + 3 * IQR
# Out:
# 3.67

# %% [markdown]
# Посчитаем долю явных выбросов (не забудем учесть пропуски):

# %%
(1 - df.query('@Q1 - 3*@IQR < ceiling_height < @Q3 + 3*@IQR')['ceiling_height'].count() / 
 df[~df['ceiling_height'].isna()]['ceiling_height'].count())
# Out:
# 0.014792693937078938

# %% [markdown]
# Доля явных выбросов 1.1%, избавимся от них (чтобы вместе с выбросами не отбросить пропуски напишем `ceiling_height != ceiling_height`, так как *None* не равен самому себе по определению):

# %%
df_filt = df.query('(@Q1 - 3*@IQR < ceiling_height < @Q3 + 3*@IQR) or ceiling_height != ceiling_height')

# %%
df_filt['ceiling_height'].describe()
# Out:
# count    14186.000000
# mean         2.709365
# std          0.233923
# min          1.750000
# 25%          2.500000
# 50%          2.650000
# 75%          2.800000
# max          3.660000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Минимальное значение в 1.75 метра все равно выглядит странно, может быть это ошибка ввода и было 2.75? Посмотрим долю значений меньше 2.5 метров:

# %%
(df_filt.query('ceiling_height < 2.5')['ceiling_height'].count() / 
 df_filt[~df_filt['ceiling_height'].isna()]['ceiling_height'].count())
# Out:
# 0.005004934442408008

# %% [markdown]
# Доля таких значений менее 0.5%, избавимся от них:

# %%
df_filt = df_filt.query('ceiling_height >= 2.5 or ceiling_height != ceiling_height')

# %% [markdown]
# Сравним основные статистические характеристики до и после фильтрации:

# %%
df['ceiling_height'].describe()
# Out:
# count    14399.000000
# mean         2.769387
# std          1.249022
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
df_filt['ceiling_height'].describe()
# Out:
# count    14115.000000
# mean         2.711208
# std          0.232728
# min          2.500000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max          3.660000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Значения максимума и минимума выглядят правдоподобно. Среднее значение стало ближе к медианному.

# %% [markdown]
# Посмотрим на гистограмму параметра высоты потолков после фильтрации:

# %%
df_filt['ceiling_height'].plot(
    kind='hist', 
    grid=True, 
    bins='fd', 
    figsize=(16, 6))
plt.show()

# %% [markdown]
# Выделяются отдельные пики в распределении.
# В одном из выводов предыдущего раздела уже упоминалось, что отдельные пики в распределении - скорее всего это типовая высота потолков в многоквартирных домах, построенных в разное время (по разным стандартам), так же играет роль класса жилья.
# Например - 2,55 метра — это стандартная высота потолков в жилых помещениях (однако, по современным правилам потолки не могут быть ниже 2,5 метра). Потолки в новостройках обычно бывают 2,7 метра, но все зависит от класса жилья. Если жилье бизнес-класса, то высота потолков скорее всего будет больше.

# %% [markdown]
# Заполним пропущенные значения в столбце. Как правило, разные типы домов имеют определенное число этажей. Сгруппируем медианную высоту потолка по числу этажей в доме:

# %%
floors_total_grouping = df_filt.groupby('floors_total')
floors_total_grouping_median_height = floors_total_grouping['ceiling_height'].median()

# %%
floors_total_grouping_median_height.plot(kind='bar', 
                                         ylim=2, 
                                         figsize=(16,4), 
                                         title='Зависимость медианной высоты потолков от числа этажей в доме');

# %%
df_filt['ceiling_height'] = df_filt['ceiling_height'].fillna(floors_total_grouping['ceiling_height'].transform('median'))
print ('Осталось пустых ячеек:', df_filt['ceiling_height'].isna().sum())
# Out:
# Осталось пустых ячеек: 1

# %% [markdown]
# Одна ячейка осталась незаполненной, заполним ее общей медианой:

# %%
df_filt['ceiling_height'] = df_filt['ceiling_height'].fillna(df_filt['ceiling_height'].median())

# %% [markdown]
# #### Параметр длительность продажи квартиры

# %% [markdown]
# Продолжим работу с отфильтрованным датасетом. Построим диаграмму размаха для параметра длительность продажи квартиры:

# %%
df_filt.boxplot('days_exposition', figsize=(16, 6));

# %% [markdown]
# Перезапишем квартили и интерквартильные расстояния для параметра стоимости квартиры, и посчитаем верхнюю грацниу "усов"

# %%
Q1 =  df_filt['days_exposition'].quantile(0.25)
Q3 = df_filt['days_exposition'].quantile(0.75)
IQR = Q3 - Q1
Q3 + 3 * IQR
# Out:
# 789.0

# %% [markdown]
# Судя по расчету, все значения длительность продажи квартир в объявлениях превышающие 823 день - выбросы. Выясним их долю (важно не забыть о пропущенных значениях и учесть это):

# %%
(1 - df_filt.query('@Q1 - 3*@IQR < days_exposition < @Q3 + 3*@IQR')['days_exposition'].count() 
     / 
     df_filt[~df_filt['days_exposition'].isna()]['days_exposition'].count())
# Out:
# 0.02987389911929539

# %% [markdown]
# Доля выбросов в столбце **days_exposition** - 2.7%. Такие данные удалять не будем, возможно есть причины по которой квартиры продавались дольше - это ценная информация.

# %% [markdown]
# #### Доля отброшенных выбросов

# %% [markdown]
# Интересна доля всех отброшенных выбросов, посчитаем ее:

# %%
(df.shape[0] - df_filt.shape[0]) / df.shape[0]
# Out:
# 0.012151812074793548

# %% [markdown]
# И общая доля потери информации (выбросы и пропуски):

# %%
(len_df_before - df_filt.shape[0]) / len_df_before
# Out:
# 0.025823874425081227

# %% [markdown]
# Около 2.5 % выбросов и пропусков в датасете отброшено, отфильтрованный от них датасет помещен в датафрейм `df_filt` для дальнешего анализа.

# %% [markdown]
# #### Вывод: фильтрация редких и выбивающихся значений

# %% [markdown]
# 1) Выбросы в столбце с параметром высоты потолка отфильтрованы, пропуски заполнены по группам числа этажей в доме. Остальные редкие значения сохранены - так как это важная информация.
#
# 2) Отфильтрованный датасет перезаписан в датафрейм `df_filt`.
#
# 3) Доля отброшенных выбросов составляет 1.2%.

# %% [markdown]
# ### Выявление параметров, влияющих на стоимость квартиры

# %% [markdown]
# Посмотрим параметры коррелирующие со стоимостью квартиры:

# %%
df_filt.corr()['last_price'].sort_values(ascending=False)
# Out:
# last_price                    1.000000
# price_for_square_meter        0.737033
# total_area                    0.634013
# living_area                   0.539616
# kitchen_area                  0.512957
# rooms                         0.351134
# ceiling_height                0.264219
# ponds_around_3000             0.210609
# parks_around_3000             0.192296
# total_images                  0.097607
# days_exposition               0.069057
# floor                         0.034058
# is_apartment                  0.019029
# balcony                       0.010468
# open_plan                     0.007872
# floors_total                  0.005213
# month                         0.003485
# day_of_week                   0.002793
# living_area_to_total_area    -0.000058
# studio                       -0.007581
# parks_nearest                -0.010829
# airports_nearest             -0.023650
# year                         -0.038416
# kitchen_area_to_total_area   -0.084154
# ...

# %% [markdown]
# Выделим интересные особенности.
#
# Стоимость квартиры положительно коррелирует со столбцами, содержащими значения:
#
# - площади недвижимости (`total_area`, `living_area`, `kitchen_area`), значения коэффициентов корреляции Пирсона 0.63, 0.54 и 0.51 соответственно;
# - числа комнат (`rooms`), значение коэффициента корреляции Пирсона 0.35;
# - высоты потолка (`ceiling_height`), значение коэффициента корреляции Пирсона 0.26;
# - числа водоемов в радиусе 3 км (`ponds_around_3000`), значение коэффициента корреляции Пирсона 0.21;
# - числа парка в радиусе 3 км (`parks_around_3000`), значение коэффициента корреляции Пирсона 0.19.
#
# Стоимость квартиры отрицательно коррелирует со столбцами содержащими значения:
#
# - расстояние до центра города (`city_centers_nearest`), значение коэффициента корреляции Пирсона -0.20. Выглядит логично - чем удаленее цетр города, тем меньше стоимость недвижимости.
#
# Остальные корреляции совсем слабые - их рассматривать мы не будем. В случае первого - число объявлений не может повлиять на стоимость квартиры, но люди, как правило, трепетно относятся к дорогим вещам - поэтому корреляция положительная. В случае отношения площади кухни к общей площади - корреляция в знаменателе отношения просто перевешивает кореляцию в числителе.
#
# Зависимость стоимости от этажа квартиры смотреть будет неинформативно, так как суммарное число этажей разная в зависимости от конкретной квартиры. Именно поэтому, ранее мы создавали столбец `floor_category` с одной из трех категорий этажа квартиры :
# - первый;
# - другой;
# - последний.

# %% [markdown]
# Происследуем детально корреляции стоимости квартиры с:
#
# 1) ее площадью;
#
# 2) числом ее комнат;
#
# 3) высотой ее потолка;
#
# 4) категорией ее этажа (первый, другой, последний).
#
# 5) числом водоемов и парков в радиусе 3 км от квартиры;
#
# Также дополнительно происследуем зависиомсть стоимости квартиры от даты публикации объявлений (дня недели, месяца, года).

# %% [markdown]
# #### Зависимость стоимости от общей площади квартиры

# %% [markdown]
# Самый большой и положительный коэффициент корреляции Пирсона был у значений относящихся к площади недвижимости.

# %% [markdown]
# Построим график зависимости стоимости квартиры от ее общей площади:

# %%
df_filt.pivot_table(index='total_area',values='last_price').plot(
    y='last_price',
    style='o',
    alpha=0.4,
    figsize=(16, 6),
    grid=True);

# %% [markdown]
# Стоимость жилья линейно растет с увеличением количества $м^{2}$ общей площади квартиры. Интересно, что с увеличением площади разброс стоимости начинает расширятся, возможно это связано с другими параметрами.

# %% [markdown]
# Так как жилая площадь и площадь кухни напрямую зависит от общей площади - смотреть такие зависимости будет не очень интересно, они будут повторять зависимость стоимости от общей площади.

# %% [markdown]
# ##### Вывод: зависимость стоимости от общей площади квартиры

# %% [markdown]
# 1) Стоимость жилья линейно растет с увеличением количества $м^{2}$ общей площади квартиры.
#
# 2) Интересно, что с увеличением площади разброс стоимости начинает расширятся, возможно это связано с другими параметрами.

# %% [markdown]
# #### Зависимость стоимости недвижимости от числа комнат

# %% [markdown]
# Здесь нагляднее будет использовать баровый график:

# %%
df_filt.pivot_table(
    index='rooms',
    values=['last_price',]).plot(
    kind='bar', 
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Наглядно также показать сводную таблицу:

# %%
df_pivot_rooms = df_filt.pivot_table(index='rooms', values='last_price', aggfunc=['mean', 'count'])
df_pivot_rooms.columns = [['mean_price', 'count']]

# %%
df_pivot_rooms
# Out:
#          mean_price count
# rooms
# 1      3.827312e+06  7951
# 2      5.568787e+06  7813
# 3      8.126561e+06  5707
# 4      1.304399e+07  1140
# 5      2.170460e+07   301
# 6      3.072253e+07    96
# 7      4.943348e+07    50
# 8      3.873900e+07    10
# 9      3.415236e+07     8
# 10     2.616667e+07     3
# 11     2.525000e+07     2
# 12     4.200000e+08     1
# 14     2.682950e+07     2
# 15     6.500000e+07     1
# 16     2.850000e+07     1
# 19     3.225000e+07     1

# %% [markdown]
# Так как квартир с более 8 комнатами достаточно мало, уберем их с графика:

# %%
df_filt.pivot_table(
    index='rooms',
    values=['last_price',]).plot(
    kind='bar', 
    figsize=(16, 6), 
    grid=True)
plt.xlim([0, 6.5]);
plt.ylim([0, 60000000]);

# %% [markdown]
# ##### Вывод: зависимость стоимости от числа комнат

# %% [markdown]
# 1) Стоимость недвижимости нелинейно растет от числа комнат.
#
# 2) Средняя стоимость квартир:
#
# - однокомнатная - 3.82 млн.;
# - двухкомнтная - 5.56 млн.;
# - трехкомнатная - 8.12 млн.;
# - четырехкомнатная - 13.0 млн.;
# - пятикомнатная - 21.7 млн.;
# - шестикомнатная - 30.7 млн.;
# - семикомнатная - 49.4 млн.

# %% [markdown]
# #### Зависимость стоимости от  высоты потолков

# %% [markdown]
# Ранее мы выяснили, что распределение значений высоты потолков в объявлений представялет собой совокупность множества отдельных пиков - типовой высоты потолков в многоквартирных домах построенных по разным стандартам и для разного сегмента покупателя (высокий, средний и низкий класс). Из-за этого, множество точек на графике могут просто сливаются друг с другом, поэтому наличие одного лишь графика зависимости будет неинформативным.
#
# Построим график зависимости стоимости от высоты потолков совместно с гистограммой для параметра высоты потолков.

# %%
df_filt.pivot_table(index='ceiling_height',values='last_price').plot(
    style='o', 
    alpha=1, 
    figsize=(16, 6), 
    grid=True)
plt.show()
df_filt['ceiling_height'].plot(
    kind='hist', 
    alpha=1, 
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Наблюдается линейная зависимость стоимости квартиры от высоты потолков. Причем с ростом высоты потолка диапазон стоимости квартир начинает плаво расширятся - это связано с малой долей квартир с высокими потолками.

# %% [markdown]
# ##### Вывод: Зависимость стоимости от высоты потолков

# %% [markdown]
# 1) Высокие потолки положительно сказываются на стоимости недвижимости. Наблюдается четкая линейная зависимость стоимости квартиры от высоты потолков. Причем с ростом высоты потолка диапазон стоимости квартир начинает плаво расширятся.
#
# 2) Зависимость высоты потолков от стоимости жилья на матрице диаграмм рассеяния представляет собой совокупность "полок" и размазанных между ними полок. Скорее всего полки относятся к типовым постройкам, а размазанные между ними точки к нетиповым проектам.

# %% [markdown]
# #### Зависимость стоимости квартиры от этажа

# %% [markdown]
# Принадлежность к той или иной категории удобно отображать гитограммами:

# %%
df_filt.pivot_table(index='floor_category',values='last_price').plot(
    kind='bar', 
    figsize=(12,12), 
    grid=True);

# %% [markdown]
# Последний этаж самый дорогой - скорее всего сюда вносит свой вклад элитное жилье. Квартиры на промежуточном этаже, в среднем, имеют более высокую стоимость чем на первом.

# %% [markdown]
# ##### Вывод: зависимость стоимости квартиры от этажа

# %% [markdown]
# Получился ожидаемый результат. Последний этаж самый дорогой - скорее всего сюда вносит свой вклад элитное жилье. Квартиры на промежуточном этаже ценятся выше, нежели на первом. Возможно это связано с возможными сопутствующими проблемами при выброе первого или последнего этажа (для первого, например - неприятные запахи из подвала, для последнего - может потечь крыша.

# %% [markdown]
# #### Зависимость стоимости от числа водоемов и парков в радиусе 3 км

# %% [markdown]
# Эти зависимости нагляднее представить в виде барных графиков:

# %%
df_filt.pivot_table(index='ponds_around_3000',values='last_price').plot(
    kind='bar',
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Чем больше водоемов - тем выше стоимость квартиры.

# %%
df_filt.pivot_table(index='parks_around_3000',values='last_price').plot(
    kind='bar',
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# С парками дело обстоит схожим образом, практически линейная зависимость.

# %% [markdown]
# ##### Вывод: зависимость стоимости от числа водоемов и парков в радиусе 3 км

# %% [markdown]
# На стоимость недвижимости положительно виляет наличие в радиусе 3 км водоемов и парков, причем чем их больше - тем, как правило, выше стоимость недвижимости.

# %% [markdown]
# #### Зависимость стоимости от удаленности от центра города

# %%
df_filt.pivot_table(index='city_centers_nearest',values='last_price').plot(
    style='o', 
    alpha=0.2, 
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Плотность точек представляет собой несколько сегментов:
#
# - первый сегмент от 0 до 10 тыс. метров - плотность темнее у высокой стоимости, также присутствуют квартиры с очень высокой стоимостью
# - второй сегмент от 10 до 20 тыс. метров - стоиомтсь квартир монотонно снижается, особенно дорогих квартир все меньше
# - третий сегмент от 20 до 38 тыс. метров стоимость квартир выходит на насыщение, практически представляя собой прямую линию. Выделяются дорогие квартиры, возможно имеют место элитные загородные дома.
# - четвертый сегмент - небольшое количество точек с относительно самой низкой стоимостью, выделяются населенные пункты близлежащие к Санкт-Петербургу.
#
# Вывод из графика довольно очевиден - чем ближе к центру города - тем выше диапазон изменения стоимости квартир, зависимость похожа на линейную до приближения к среднему сегменту города, далее стоимость начинает очень сильно меняться - зависимость похожа на экспоненциальную.
#
# Большой разброс стоимости квартир в центре скорее всего связан с различным классом жилья (средний и высокий, реже - низкий).

# %% [markdown]
# ##### Вывод: зависимость стоимости от удаленности от центра города

# %% [markdown]
# Стомость недвижимости, как и разброс стоимости, линейно падает с удаленностью от центра города, а потом выходит на "насыщение"

# %% [markdown]
# #### Зависимость стоимости от даты размещения

# %% [markdown]
# Для начала построим зависимость стоимости недвижимости от года размещения в виде барового графика:

# %%
df_filt.pivot_table(index='year',values='last_price').plot(
        kind='bar', 
        figsize=(16, 6), 
        grid=True);

# %% [markdown]
# Интересный результат. На баровом графике можно наблюдать реакцию рынка недвижимости на последствия экономического кризиса в 2014 году. В 2014 году были введены антироссийские санкции - упала национальная валюта. Все это отразилось на рынке недвижимости сокращением спроса, снижением темпов строительства, уменьшением рублевых цен. К 2019 году наблюдается небольшой рост стоимости недвижимости по сравнению с предыдущими годами.

# %% [markdown]
# Построим зависимость стоимости недвижимости от месяца размещения:

# %%
df_filt.pivot_table(index='month',values='last_price').plot(
    kind='bar', 
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Проанализируем по кварталам:
#
# - в первом квартале стоимость практически не изменяется;
# - второй квартал начинается с возрастания цен и плавной коррекции к его концу;
# - к концу третьего квартала цены на недвижимость растут;
# - четвертый квартал начинается с коррекции цен, затем идет плавный рост цен впольть до конца года.

# %% [markdown]
# Построим зависимость стоимости недвижимости от дня недели размещения:

# %%
df_filt.pivot_table(index='day_of_week',values='last_price').plot(
    kind='bar', 
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Практически равномерное распределение.

# %% [markdown]
# Построим сводную таблицу чтобы выявить средне-недельный максимум и минимум стоимости:

# %%
df_pivot_datetime = df_filt.pivot_table(index='day_of_week',values='last_price', aggfunc=['mean', 'count'])
df_pivot_datetime.columns = [['mean_price', 'count']]

# %%
df_pivot_datetime
# Out:
#                mean_price count
# day_of_week
# 0            6.382813e+06  3525
# 1            6.332918e+06  4085
# 2            6.512270e+06  3871
# 3            6.518172e+06  4173
# 4            6.261164e+06  3884
# 5            6.950295e+06  1894
# 6            6.205751e+06  1655

# %% [markdown]
# Максимум стоимости приходится на субботу (6.95 млн.), минимум на воскресенье (6.2 млн.). Больше всего объявлений опубликовано в будние дни, а именно со вторника по пятницу.

# %% [markdown]
# ##### Вывод: зависимость стоимости от даты размещения

# %% [markdown]
# 1) В зависимости стоимости от года публикации можно наблюдать реакцию рынка недвижимости на последствия экономического кризиса в 2014 году, это выражается падением стоимости жилья.
#
# 2) В первых двух кварталах стоимость жилья либо меняется незначительно, либо падает. В двух последних кварталах происходит монотонный рост стоимости к концу кварталов.
#
# 3) По дням, в целом, имеем равномерное распределение. Стоит отметить максимум - суббота (6.95 млн.), и минимум - воскресенье (6.2 млн.).
#
# 4) Больше всего объявлений публикуют в будние дни.

# %% [markdown]
# #### Вывод: выявление параметров, влияющих на стоимость квартиры

# %% [markdown]
# 1) На стоимость жилья сильно влияют параметры квартиры: площадь, число комнат, этаж, число парков и водоемов поблизости, удаленность от центра города. Из них определяющими являются конечно же площадь и удаленность от центра города.
#
# 2) Параметр площади неразрывно связан с числом комнат. Однако пока стоимость линейно растет от площади, число комнат сильно виляет на стоимость лишь до "насыщения" числа комнат. Например - стоимость трехкомнатной и четырехкомнатной квартиры не так сильно отличается, как например однокомнтная от двухкомнатной или двухкомнатная от трехкомнатной.
#
# 3) Средняя стоимость квартир по числу комнат:
#
# - однокомнатная - 3.82 млн.;
# - двухкомнтная - 5.56 млн.;
# - трехкомнатная - 8.12 млн.;
# - четырехкомнатная - 13.0 млн.;
# - пятикомнатная - 21.7 млн.;
# - шестикомнатная - 30.7 млн.;
# - семикомнатная - 49.4 млн.
#
# 4)  Последний этаж самый дорогой - скорее всего сюда вносит свой вклад элитное жилье. Квартиры на промежуточном этаже ценятся выше, нежели на первом. Возможно это связано с возможными сопутствующими проблемами при выброе первого или последнего этажа (для первого, например - неприятные запахи из подвала, для последнего - может потечь крыша.
#
# 5) На стоимость квартиры положительно виляет наличие в радиусе 3 км водоемов и парков, причем чем их больше - тем, как правило, выше стоимость недвижимости.
#
# 6) Стомость недвижимости резко падает в первом сегменте удаленности от цнетра города и линейно падает с удаленностью от центра города в среднем и низком сегменте города.
#
# 7) В зависимости стоимости от года публикации можно наблюдать реакцию рынка недвижимости на последствия экономического кризиса в 2014 году, это выражается падением стоимости жилья.  В течении года к лету спорс на квартиры падает - рынок немного корректируется и растет во второй половине года. В остальное время года имеем практически равномерное распределение. По дням, в целом, имеем равномерное распределение. Больше всего объявлений публикуют в будние дни (вторник-пятница).

# %% [markdown]
# ### Топ-10 населенных пунктов с наибольшим числом объявлений

# %% [markdown]
# Выделим топ-10 населенных пунктов по количеству объявлений:

# %%
top_10 = df_filt['locality_name'].value_counts().head(10).index.to_list()
top_10
# Out:
# ['санкт-петербург',
#  'мурино',
#  'кудрово',
#  'шушары',
#  'всеволожск',
#  'пушкин',
#  'колпино',
#  'парголово',
#  'гатчина',
#  'выборг']

# %% [markdown]
# Запишем срез по топ-10 населенных пунктов в новый датафрейм **df_top_10**:

# %%
df_top_10 = df_filt.query('locality_name in @top_10')

# %% [markdown]
# Посчитаем среднюю цену за $м^{2}$ в каждом из населенных пунктов и выведем в сводной таблице топ-10 городов самой высокой стоимости за 1 $м^{2}$ жилья:

# %%
df_top_10.pivot_table(
    index='locality_name', 
    values='price_for_square_meter').sort_values(
    by='price_for_square_meter', 
    ascending=False).round()
# Out:
#                  price_for_square_meter
# locality_name
# санкт-петербург                114243.0
# пушкин                         102623.0
# кудрово                         95084.0
# парголово                       90320.0
# мурино                          85505.0
# шушары                          78254.0
# колпино                         75444.0
# гатчина                         68811.0
# всеволожск                      68580.0
# выборг                          58189.0

# %% [markdown]
# Построим баровый график отношения:

# %%
df_top_10.pivot_table(
    index='locality_name', 
    values='price_for_square_meter').sort_values(
    by='price_for_square_meter', 
    ascending=False).round().plot(
    kind='bar',
    grid=True,
    figsize=(16, 6)
    )
plt.tick_params(axis='both', which='major', labelsize=20)

# %% [markdown]
# #### Вывод: топ-10 населенных пунктов с наибольшим числом объявлений

# %% [markdown]
# 1) Практически линейное снижение стоимости квартир в зависимости от удаления от города Санкт-Петербург.
#
# 2) Цена за $м^{2}$ открывающего топ-10 Санкт-Петербурга практически в два раза превосходит стомость посленго в топ-10 города - Выборга.

# %% [markdown]
# ### Изучение предложения квартир

# %% [markdown]
# Выделим объвления в Санкт-Петербурге в датафрейм `df_spb`:

# %%
df_spb = df_filt.query('locality_name in "санкт-петербург"')

# %% [markdown]
# Напишем функцию перевода метров в километры (не забываем, что мы работаем со столбцом имеющим пропуски, с ними нужно обходиться деликатно):

# %%
def meter_to_km(row):
    meter = row
    if meter != meter:
        return meter
    km = round(meter / 1000)
    return km

# %% [markdown]
# Создадим столбец `city_centers_nearest_km`, и перепишем туда значения столбца `city_centers_nearest` в километрах с помощью функции:

# %%
df_spb['city_centers_nearest_km'] = df_spb['city_centers_nearest'].apply(meter_to_km)

# %% [markdown]
# Прежде чем считать цену каждого километра - выясним, нет ли в параметре удаленности от центра города нулей.

# %%
df_spb.query('city_centers_nearest_km == 0')['city_centers_nearest_km'].count()
# Out:
# 22

# %% [markdown]
# Есть 22 нуля. Если их не убрать и разделить на нули - возникнут *None*. Нужно этого избежать. Так как мы ранее округляли до целого километра - исправим нули на единицы.

# %%
df_spb['city_centers_nearest_km'] = df_spb['city_centers_nearest_km'].replace(0, 1)

# %% [markdown]
# Пересчитаем нули:

# %%
df_spb.query('city_centers_nearest_km == 0')['city_centers_nearest_km'].count()
# Out:
# 0

# %% [markdown]
# Рассчитаем цену каждого километра и запишем в новый столбец `price_for_km`:

# %%
df_spb['price_for_km'] = df_spb['last_price'] / df_spb['city_centers_nearest_km']

# %% [markdown]
# Выведем значения средней стоимости для каждого километра в сводной таблице:

# %%
df_spb.pivot_table(index='city_centers_nearest_km', values='price_for_km')
# Out:
#                          price_for_km
# city_centers_nearest_km
# 1.0                      2.239370e+07
# 2.0                      8.617431e+06
# 3.0                      3.708543e+06
# 4.0                      3.237014e+06
# 5.0                      2.778656e+06
# 6.0                      2.378593e+06
# 7.0                      2.087595e+06
# 8.0                      1.246365e+06
# 9.0                      7.719650e+05
# 10.0                     6.517974e+05
# 11.0                     5.654699e+05
# 12.0                     4.881021e+05
# 13.0                     4.702904e+05
# 14.0                     4.039391e+05
# 15.0                     3.925353e+05
# 16.0                     3.366392e+05
# 17.0                     3.135770e+05
# 18.0                     2.838347e+05
# 19.0                     2.674538e+05
# 20.0                     3.025909e+05
# 21.0                     2.628226e+05
# 22.0                     2.461602e+05
# 23.0                     2.199719e+05
# ...

# %%
df_spb.pivot_table(
    index='city_centers_nearest_km', 
    values='price_for_km').plot(
    figsize=(16, 6),
    grid=True);

# %% [markdown]
# По харатеру функции можно определить сегмент сегмент квартир в центре города - он на том участке где скорость изменения функции самая высокая (производная максимальна). Примем за центр города интервал от 0 до 7.5 км (далее характер функции меняется).

# %% [markdown]
# #### Вывод: изучение предложения квартир
#
# 1) Сегмент квартир в центре - зона с радиусом от 0 до 7.5 км от центра.
#
# 2) Средним сегментом можно назвать зону с радиусом от 7.5 до 15 км от центра.
#
# 3) Окраиной можно назвать зону с радиусом от 15 до 30 км от центра.

# %% [markdown]
# ### Анализ сегмента квартир в центре

# %% [markdown]
# Выделим объвления в центре Санкт-Петербурга в датафрейм **df_spb_center**:

# %%
df_spb_center = df_spb.query('city_centers_nearest_km <= 7.5')

# %% [markdown]
# Посмотрим параметры коррелирующие со стоимостью квартиры в центре:

# %%
df_spb_center.corr()['last_price'].sort_values(ascending=False)
# Out:
# last_price                    1.000000
# price_for_square_meter        0.801159
# price_for_km                  0.760743
# total_area                    0.590706
# living_area                   0.484834
# kitchen_area                  0.464557
# rooms                         0.294196
# total_images                  0.125104
# parks_around_3000             0.114548
# floor                         0.109236
# ponds_around_3000             0.108935
# airports_nearest              0.097646
# ceiling_height                0.090229
# balcony                       0.070936
# days_exposition               0.044471
# floors_total                  0.041444
# day_of_week                   0.028834
# is_apartment                  0.024898
# open_plan                     0.009740
# studio                       -0.007202
# month                        -0.012857
# living_area_to_total_area    -0.018913
# parks_nearest                -0.038068
# year                         -0.038923
# ...

# %% [markdown]
# Сравним со всеми объявлениями:

# %%
df_filt.corr()['last_price'].sort_values(ascending=False)
# Out:
# last_price                    1.000000
# total_area                    0.661671
# price_for_square_meter        0.634349
# living_area                   0.527182
# kitchen_area                  0.450117
# rooms                         0.405624
# ceiling_height                0.395704
# floors_total                  0.264461
# ponds_around_3000             0.263428
# parks_around_3000             0.222373
# floor                         0.177284
# total_images                  0.167992
# balcony                       0.092922
# parks_nearest                 0.048121
# year                          0.036337
# is_apartment                  0.018744
# days_exposition               0.018610
# living_area_to_total_area     0.011104
# month                         0.000161
# open_plan                    -0.000398
# airports_nearest             -0.015683
# day_of_week                  -0.015784
# studio                       -0.022492
# ponds_nearest                -0.038951
# ...

# %% [markdown]
# Выделим интересные особенности.
#
# - Общая площадь теперь не так сильно коррелирует со стоимостью (было 0.66 стало 0.59);
# - Сильная связь стоимости и стоимости за метр квадратный, и удаленности от центра.
#
#
# Повторим ранее оговоренную условность:
# Зависиость стоимости от этажа квартиры смотреть будет неинформативно, так как суммарное число этажей разная в зависимости от конкретной квартиры. Именно поэтому, ранее мы создавали столбец **floor_category** с одной из трех категорий этажа квартиры :
# - первый;
# - другой;
# - последний.

# %% [markdown]
# Происследуем детально корреляции стоимости квартиры в центре с:
#
# 1) ее площадью;
#
# 2) числом ее комнат;
#
# 3) высотой ее потолка;
#
# 4) категорией ее этажа (первый, другой, последний);
#
# 5) числом водоемов и парков в радиусе 3 км от квартиры.

# %% [markdown]
# #### Зависимость стоимости от общей площади квартиры в центре

# %% [markdown]
# Построим график зависимости стоимости квартиры в центре от ее общей площади и сравним ее с той же зависимостью во всех объявлениях:

# %%
ax = df_spb_center.pivot_table(index='total_area', values='last_price').plot(
    y='last_price',
    label='Санкт-Петербург',
    style='o',
    alpha=0.6,
    figsize=(16, 6),
    grid=True,
    );

# %% [markdown]
# Характер зависимости практически не изменился. Стоимость жилья практически линейно зависит от площади.

# %% [markdown]
# ##### Вывод: зависимость стоимости квартиры в центре от ее площади

# %% [markdown]
# 1) Зависимость стоимости жилья от общей площади квартиры похожа на линейную, причем чем больше площадь, тем больше разброс стоимости.

# %% [markdown]
# #### Зависимость стоимости квартиры в центре от числа комнат

# %% [markdown]
# Здесь нагляднее будет использовать баровый график и сравним его с графиком для всех объявлений (т.к. квартир с числом комнат более 8 мало - исключим их из графика):

# %%
ax = df_spb_center.pivot_table(
    index='rooms',
    values=['last_price',]).plot.bar(
    figsize=(16, 6), 
    grid=True,
    color='red', label ='spb')
df_filt.pivot_table(
    index='rooms',
    values=['last_price',]).plot.bar(
    figsize=(16, 6), 
    grid=True,
    ax=ax, label ='all');
plt.xlim([0, 6.5]);
plt.ylim([0, 60000000]);

# %% [markdown]
# В СПБ средняя стоимость этажа выше, чем среди всех объявлений - все логично.

# %% [markdown]
# Наглядно также показать сводные таблицы в центре и среди всех объявлений:

# %%
df_pivot_rooms_spb_center = df_spb_center.pivot_table(index='rooms', values='last_price', aggfunc=['mean', 'count'])
df_pivot_rooms_spb_center.columns = [['mean_price', 'count']]

# %%
df_pivot_rooms_spb_center
# Out:
#          mean_price count
# rooms
# 1      6.800196e+06   501
# 2      9.754529e+06  1006
# 3      1.481133e+07  1042
# 4      1.894402e+07   463
# 5      2.615779e+07   192
# 6      3.416454e+07    76
# 7      5.157891e+07    46
# 8      3.531125e+07     8
# 9      4.466667e+07     3
# 10     2.775000e+07     2
# 11     2.525000e+07     2
# 14     2.865900e+07     1
# 15     6.500000e+07     1
# 16     2.850000e+07     1
# 19     3.225000e+07     1

# %%
df_pivot_rooms
# Out:
#          mean_price count
# rooms
# 1      3.827312e+06  7951
# 2      5.568787e+06  7813
# 3      8.126561e+06  5707
# 4      1.304399e+07  1140
# 5      2.170460e+07   301
# 6      3.072253e+07    96
# 7      4.943348e+07    50
# 8      3.873900e+07    10
# 9      3.415236e+07     8
# 10     2.616667e+07     3
# 11     2.525000e+07     2
# 12     4.200000e+08     1
# 14     2.682950e+07     2
# 15     6.500000e+07     1
# 16     2.850000e+07     1
# 19     3.225000e+07     1

# %% [markdown]
# Характер зависимости в целом не изменился, зато выросла средняя стоимость квартир с разным числом комнат.

# %% [markdown]
# ##### Вывод: зависимость стоимости квартиры в центре от числа комнат

# %% [markdown]
# 1) Характер зависимости стоимости квартиры от числа комнат в центре не отчлиается от характера той же зависимости для всех объявлений
#
# 2) Средняя стоимость квартир в центре:
#
# - однокомнатная - 6.8 млн. (в среднем, дороже на 3 млн.);
# - двухкомнтная - 9.7 млн.  (в среднем, дороже на 4.2 млн.);
# - трехкомнатная - 14.8 млн.  (в среднем, дороже на 4.7 млн.);
# - четырехкомнатная - 18.9 млн.  (в среднем, дороже на 5 млн.).

# %% [markdown]
# #### Зависимость стоимости квартиры в центре от  высоты потолков

# %% [markdown]
# Построим график зависимости стоимости от высоты потолков совместно с гистограммой для параметра высоты потолков и сравним с тем же графиком и гистограммой для всех объявлений:

# %%
df_spb_center.pivot_table(index='ceiling_height',values='last_price').plot(
    style='o', 
    alpha=1, 
    figsize=(16, 6), 
    grid=True)
plt.show()
df_spb_center['ceiling_height'].plot(
    kind='hist', 
    alpha=1, 
    figsize=(16, 6), 
    grid=True);

# %%
df_filt.pivot_table(index='ceiling_height',values='last_price').plot(
    style='o', 
    alpha=1, 
    figsize=(16, 6), 
    grid=True)
plt.show()
df_filt['ceiling_height'].plot(
    kind='hist', 
    alpha=1, 
    figsize=(16, 6), 
    grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# В центре больше квартир с высокими потолками.

# %% [markdown]
# ##### Вывод: Зависимость стоимости квартиры в центре от высоты потолков

# %% [markdown]
# Квартир с высокими потолками, в среднем, в центре больше, чем среди всех объявлений.

# %% [markdown]
# #### Зависимость стоимости квартиры в центре от этажа

# %% [markdown]
# Построим баровый график зависимости стоимости квартиры от категории этажа, для квартир в центре Санкт-Питербурга и среди всех объявлений:

# %%
floor_stat = df_spb_center.pivot_table(index='floor_category',values='last_price').merge(
    df_filt.pivot_table(index='floor_category',values='last_price'), on='floor_category', how='inner')
floor_stat.columns = ['Санкт-Петербург', 'Все объявления']

# %%
ax = floor_stat.plot(y=['Санкт-Петербург', 'Все объявления'], kind='bar', figsize=(16, 6), grid=True)
ax.set_xlabel('Категория этажа')
ax.set_ylabel('Средняя стоимость');

# %% [markdown]
# Зависимость сохраняется.

# %% [markdown]
# ##### Вывод: зависимость стоимости квартиры в центре от этажа

# %% [markdown]
# Получился ожидаемый результат. Зависимость точно такая же, как и среди всех объявлений. Отличается только средняя стоиомсть жилья (В СПБ больше).

# %% [markdown]
# #### Зависимость стоимости квартиры в центре от числа водоемов и парков в радиусе 3 км

# %% [markdown]
# Построим зависимости стоимости квартиры от числа водоемов и парков в радиусе 3 км в виде барных графиков для квартир в центре и среди всех объявлений:

# %%
ponds_stat = df_spb_center.pivot_table(index='ponds_around_3000',values='last_price').merge(
    df_filt.pivot_table(index='ponds_around_3000',values='last_price'), on='ponds_around_3000', how='inner')
ponds_stat.columns = ['Санкт-Петербург', 'Все объявления']

# %%
ax = ponds_stat.plot(y=['Санкт-Петербург', 'Все объявления'], kind='bar', figsize=(16, 6), grid=True)
ax.set_xlabel('Категория этажа')
ax.set_ylabel('Средняя стоимость');

# %% [markdown]
# Похоже, что в центре уже все равно: есть рядом водоем или нет. Стоимость квартир в зависимости от числа водоемов практически не менятся (если он либо есть, либо его нет. при увеличении числа водоемов от 2 и более - цена монотонно растет).

# %%
parks_stat = df_spb_center.pivot_table(index='parks_around_3000',values='last_price').merge(
    df_filt.pivot_table(index='parks_around_3000',values='last_price'), on='parks_around_3000', how='inner')
parks_stat.columns = ['Санкт-Петербург', 'Все объявления']

# %%
ax = parks_stat.plot(y=['Санкт-Петербург', 'Все объявления'], kind='bar', figsize=(16, 6), grid=True)
ax.set_xlabel('Категория этажа')
ax.set_ylabel('Средняя стоимость');

# %% [markdown]
# Тоже самое и для числа праков в радиусе 3 км.

# %% [markdown]
# ##### Вывод: зависимость стоимости квартиры в центре от числа водоемов и парков в радиусе 3 км

# %% [markdown]
# 1) На стоимость квартир в центре практические не влияет наличие рядом парков и водоемов (если он либо есть, либо его нет. при увеличении числа водоемов от 2 и более - цена монотонно растет).

# %% [markdown]
# #### Зависимость стоимости квартиры в центре от удаленности от центра города

# %% [markdown]
# Построим зависимость стоимости квартиры от удаленности от центра города для объявлений о продаже квартир в центре и среди всех объявлений:

# %%
df_spb_center.pivot_table(index='city_centers_nearest',values='last_price').plot(
    style='o', 
    alpha=0.5, 
    figsize=(16, 6), 
    grid=True);

# %% [markdown]
# Cтоимость квартир в центральном районе практически не зависит от точного расстояния до центра

# %% [markdown]
# ##### Вывод: зависимость стоимости квартиры в центре от удаленности от центра города

# %% [markdown]
# 1) Для квартир в центре стоимость квартиры практически не зависит от параметра расстояния до центра города.

# %% [markdown]
# #### Вывод: анализ сегмента квартир в центре
#
# 1) На стоимость квартир в центре также сильно продолжают влиять параметры общей площади, числа комнат.
#
# 2) Для квартир в центре высокие потолки, наличие поблизости парков и водоемов - уже является обыденностью и эти параметры слабо вносят свою лепту в стоимость квартир.
#
# 3) Распредление средней стоимости квартир по типам этажей в целом не изменилось.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В данных достаточно много пропусков:
#
# `ceiling_height` - 38.7 % пропусков, вероятная причина - продавец не указал параметр;
# `living_area` - 8.0 % пропусков, вероятная причина - продавец не указал параметр;
# `kitchen_area` - 9.6 % пропусков, вероятная причина - продавец не указал параметр;
# `airports_nearest` - 23.4 % пропусков, причина - объявление находится в маленьком городе и аэропорта нет;
# `city_centers_nearest` - 23.3% пропусков, причина - объявление находится в маленьком городе, системе неясно что считать за центр города или он слишком далеко;
# `parks_nearest` - 65.9 % пропусков, причина - парка нет в радиусе 3 км;
# `ponds_nearest` - 61.5 % пропусков, причина - водоема нет в радиусе 3 км;
# `days_exposition` - 13.4 % пропусков, вероятная причина - сбой при сборе или обработке данных.
#
# И большое число аномалий в параметре высота потолков (`ceiling_height`) - аномальные значения отброшены, пропуски заполнены на основе группировки по числу этажей в доме. Желательно валидировать ввод высоты потолка (например, значение не должно быть менее 2.0 или иметь двузначную целую часть), многие ошибочные значения в таблице явно вызваны ошибкой при вводе или проблемой с вводом/обработкой запятой/точки.
#
# Также некоторые значения, например число этажей и картографические данные, можно было бы заполнять автоматически на основе адреса, это позволило бы избежать пропусков.
#
# Название населенного пункта желательно выбирать из списка, текущий вариант заполнения производит разнобой и дубликаты, тип населенного пункта в большинстве случаев не важен или даже вводит в заблуждение/
#
# Около 2.5 % выбросов и пропусков в датасете отброшено.
#
# При проведении исследования можно сделать выводы:
#
# 1) На стоимость жилья сильно влияют параметры квартиры: площадь, число комнат, этаж, число парков и водоемов поблизости, удаленность от центра города. Из них определяющими являются конечно же площадь и удаленность от центра города.
#
# 2) Параметр площади неразрывно связан с числом комнат. Однако пока стоимость линейно растет от площади, число комнат сильно виляет на стоимость лишь до "насыщения" числа комнат. Например - стоимость трехкомнатной и четырехкомнатной квартиры не так сильно отличается, как например однокомнатная от двухкомнатной или двухкомнатная от трехкомнатной.
#
# 3) Средняя стоимость квартир по числу комнат:
#
# однокомнатная - 3.82 млн.;
# двухкомнатная - 5.56 млн.;
# трехкомнатная - 8.12 млн.;
# четырехкомнатная - 13.0 млн.;
# пятикомнатная - 21.7 млн.;
# шестикомнатная - 30.7 млн.;
# семикомнатная - 49.4 млн.
#
# 4) Последний этаж самый дорогой - скорее всего сюда вносит свой вклад элитное жилье. Квартиры на промежуточном этаже ценятся выше, нежели на первом. Возможно это связано с возможными сопутствующими проблемами при выборе первого или последнего этажа (для первого, например - неприятные запахи из подвала, для последнего - может потечь крыша.
#
# 5) На стоимость квартиры положительно виляет наличие в радиусе 3 км водоемов и парков, причем чем их больше - тем, как правило, выше стоимость недвижимости.
#
# 6) Стоимость недвижимости резко падает в первом сегменте удаленности от центра города и линейно падает с удаленностью от центра города в среднем и низком сегменте города.
#
# 7) В зависимости стоимости от года публикации можно наблюдать реакцию рынка недвижимости на последствия экономического кризиса в 2014 году, это выражается падением стоимости жилья. В течении года к лету спрос на квартиры падает - рынок немного корректируется и растет во второй половине года. В остальное время года имеем практически равномерное распределение. По дням, в целом, имеем равномерное распределение. Больше всего объявлений публикуют в будние дни (вторник-пятница).
#
# 8) Характер зависимости стоимости квартиры (в центре СПБ) от числа комнат в центре не отличается от характера той же зависимости для всех объявлений.
#
# 2) Средняя стоимость квартир в центре СПБ:
#
# однокомнатная - 6.8 млн. (в среднем, дороже на 3 млн.);
# двухкомнатная - 9.7 млн. (в среднем, дороже на 4.2 млн.);
# трехкомнатная - 14.8 млн. (в среднем, дороже на 4.7 млн.);
# четырехкомнатная - 18.9 млн. (в среднем, дороже на 5 млн.);
# пятикомнатная - 26.1 млн. (в среднем, дороже на 5.1 млн.);
# шестикомнатная - 34.1 млн. (в среднем, дороже на 3.4 млн.);
# семикомнатная - 51.5 млн. (в среднем, дороже на 1 млн.);
#
# Стоит отметить, что квартиры с экстремально большим числом комнат (больше 6) расположены как правило в центре, поэтому разница в цене с увеличением комнат сходит на нет.
